# %%
import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten
from tensorflow.keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras.models import model_from_json
# Out:
# Using TensorFlow backend.

# %%
import numpy as np
from PIL import Image

# %%
import os
def make_data(file):
    ls=[]
    folder=r'C:\Users\PIYUSH\Documents\training_set\{}'.format(file)
    files=os.listdir(folder)
    files=list(map(lambda x: os.path.join(folder,x),files))
    a=(len(files))
    for i in range(a):
        im = Image.open(files[i]) 
        im = im.resize((64,64))
        im=np.array(im)
        #im=im.flatten()
        ls.append(im)
        
    return ls

# %%
import os
def make_data_test(file):
    ls=[]
    folder=r'C:\Users\PIYUSH\Documents\test_set\{}'.format(file)
    files=os.listdir(folder)
    files=list(map(lambda x: os.path.join(folder,x),files))
    a=(len(files))
    for i in range(a):
        im = Image.open(files[i]) 
        im = im.resize((64,64))
        im=np.array(im)
        #im=im.flatten()
        ls.append(im)
        
    return ls

# %%
cat_data_train=make_data('training_set\cats')
dog_data_train=make_data('training_set\dogs')

# %%
cat_data_test=make_data_test('test_set\cats')
dog_data_test=make_data_test('test_set\dogs')

# %%
len(dog_data_test)
# Out:
# 1012

# %%
len(cat_data_train)
# Out:
# 4000

# %%
len(dog_data_train)
# Out:
# 4005

# %%
cat_data_train[0].shape
# Out:
# (64, 64, 3)

# %%
data_train=cat_data_train+dog_data_train

# %%
len(data_train)
# Out:
# 8005

# %%
data_test=cat_data_test+dog_data_test

# %%
len(data_test)
# Out:
# 2023

# %%
data_train=np.array(data_train,dtype=float)
data_test=np.array(data_test,dtype=float)

# %%
data_test.shape
# Out:
# (2023, 64, 64, 3)

# %%
label_train=np.zeros((data_train.shape[0]))

# %%
label_train.shape
# Out:
# (8005,)

# %%
label_train[4000:]=1

# %%
label_train[7000]
# Out:
# 1.0

# %%
label_test=np.zeros((data_test.shape[0]))

# %%
label_test.shape
# Out:
# (2023,)

# %%
len(cat_data_test)
# Out:
# 1011

# %%
label_test[1011:]=1

# %%
label_test[2000]
# Out:
# 1.0

# %%
data_train.shape
# Out:
# (8005, 64, 64, 3)

# %%
a=(data_train.shape[0])
i=np.random.permutation(a)
x_train,y_train=data_train[i],label_train[i]
print(y_train.shape,x_train.shape)
# Out:
# (8005,) (8005, 64, 64, 3)

# %%
a=(data_test.shape[0])
i=np.random.permutation(a)
x_test,y_test=data_test[i],label_test[i]
print(y_test.shape,x_test.shape)
# Out:
# (2023,) (2023, 64, 64, 3)

# %%
y_train[2]
# Out:
# 0.0

# %%
x=x_train[80]

# %%
import cv2
cv2.imwrite('a.jpg',x)
# Out:
# True

# %%
y_train[80]
# Out:
# 0.0

# %%
x_train.shape[1:]
# Out:
# (64, 64, 3)

# %%
num_classes=2
y_train_main = keras.utils.to_categorical(y_train, num_classes)
y_test_main = keras.utils.to_categorical(y_test, num_classes)

# %%
classifier = Sequential()

# Convolution
classifier.add(Conv2D(32, (3, 3), input_shape = (64, 64, 3), activation = 'relu'))

# Pooling
classifier.add(MaxPooling2D(pool_size = (2, 2)))

# Adding a second convolutional layer
classifier.add(Conv2D(32, (3, 3), activation = 'relu'))
classifier.add(MaxPooling2D(pool_size = (2, 2)))

# Flattening
classifier.add(Flatten())

# Full connection
classifier.add(Dense(units = 128, activation = 'relu'))
classifier.add(Dense(units = num_classes, activation = 'sigmoid'))

# Compiling the CNN
classifier.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# %%
#opt = keras.optimizers.rmsprop(lr=0.0001, decay=1e-6)

# Let's train the model using RMSprop
classifier.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

# %%
batch_size=32
epochs=12
classifier.fit(x_train, y_train_main,
              batch_size=batch_size,
              epochs=epochs,
              validation_data=(x_test, y_test_main),
              shuffle=True)
# Out:
# Train on 8005 samples, validate on 2023 samples
# Epoch 1/12
# 8005/8005 [==============================] - 29s 4ms/sample - loss: 2.0137 - accuracy: 0.5313 - val_loss: 0.6797 - val_accuracy: 0.5509
# Epoch 2/12
# 8005/8005 [==============================] - 35s 4ms/sample - loss: 0.6533 - accuracy: 0.6059 - val_loss: 0.6890 - val_accuracy: 0.5766
# Epoch 3/12
# 8005/8005 [==============================] - 35s 4ms/sample - loss: 0.6020 - accuracy: 0.6512 - val_loss: 0.7282 - val_accuracy: 0.5704
# Epoch 4/12
# 8005/8005 [==============================] - 34s 4ms/sample - loss: 0.5209 - accuracy: 0.7280 - val_loss: 0.7631 - val_accuracy: 0.5833
# Epoch 5/12
# 8005/8005 [==============================] - 35s 4ms/sample - loss: 0.4268 - accuracy: 0.7897 - val_loss: 0.7911 - val_accuracy: 0.6070
# Epoch 6/12
# 8005/8005 [==============================] - 40s 5ms/sample - loss: 0.3407 - accuracy: 0.8378 - val_loss: 1.0606 - val_accuracy: 0.5984
# Epoch 7/12
# 8005/8005 [==============================] - 38s 5ms/sample - loss: 0.2884 - accuracy: 0.8755 - val_loss: 1.1365 - val_accuracy: 0.5850
# Epoch 8/12
# 8005/8005 [==============================] - 35s 4ms/sample - loss: 0.2196 - accuracy: 0.9072 - val_loss: 1.4164 - val_accuracy: 0.5976
# Epoch 9/12
# 8005/8005 [==============================] - 37s 5ms/sample - loss: 0.1776 - accuracy: 0.9285 - val_loss: 1.6771 - val_accuracy: 0.5823
# Epoch 10/12
# 8005/8005 [==============================] - 35s 4ms/sample - loss: 0.1429 - accuracy: 0.9439 - val_loss: 1.5250 - val_accuracy: 0.5860
# Epoch 11/12
# 8005/8005 [==============================] - 36s 5ms/sample - loss: 0.1439 - accuracy: 0.9452 - val_loss: 1.6695 - val_accuracy: 0.5971
# Epoch 12/12
# 8005/8005 [==============================] - 32s 4ms/sample - loss: 0.1101 - accuracy: 0.9603 - val_loss: 2.0565 - val_accuracy: 0.6013

# %%
scores = classifier.evaluate(x_test, y_test_main, verbose=1)
scores
# Out:
# 2023/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================== ...
# [1.955418757501358, 0.59268415]

# %%
x=np.reshape(x_test[0],(1,64,64,3))
classifier.predict_classes(x)
# Out:
# array([1], dtype=int64)

# %%
y_test[0]
# Out:
# 1.0
